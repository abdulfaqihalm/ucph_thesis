# %%
from Bio import SeqIO
import numpy as np 
import torch
from matplotlib import pyplot as plt 
import pandas as pd
import seaborn as sns
import random
import os
from scipy.stats import gaussian_kde
import sys
sys.path.append("/binf-isilon/renniegrp/vpx267/ucph_thesis/")
from wrapper.utils import plot_correlation

# %%
validation_folder = "/binf-isilon/renniegrp/vpx267/ucph_thesis/data/outputs/predictions"
i = 1
validation_file = f"/binf-isilon/renniegrp/vpx267/ucph_thesis/data/outputs/predictions/validation_{i}th_fold_dual_outputs_m6_info-no_promoter-False_TEST_MOTIF.csv"
validation_df = pd.read_csv(validation_file)
print(validation_df)
# Out:
#        true_control  true_case  pred_control  pred_case
# 0            0.1250     0.0000      0.360831   0.203998
# 1            0.6414     0.6398      0.574094   0.451873
# 2            0.1932     0.0000      0.444610   0.236376
# 3            0.3377     0.6667      0.368324   0.310962
# 4            0.3794     0.6644      0.452597   0.387212
# ...             ...        ...           ...        ...
# 27478        0.3173     0.0000      0.562392   0.391559
# 27479        0.0000     0.1382      0.326569   0.107211
# 27480        0.4722     0.0000      0.385825   0.378000
# 27481        0.7765     0.6825      0.434757   0.209347
# 27482        0.1906     0.1484      0.322432   0.149061
#
# [27483 rows x 4 columns]

# %%
plot_correlation(validation_df["true_control"], validation_df["pred_control"], title="Control Data" interactive=True)

# %%
plot_correlation(validation_df["true_case"], validation_df["pred_case"], title="Case Data", interactive=True)

# %%
for fold in range(1, 6):
    validation_folder = "/binf-isilon/renniegrp/vpx267/ucph_thesis/data/outputs/predictions"
    validation_file = f"/binf-isilon/renniegrp/vpx267/ucph_thesis/data/outputs/predictions/validation_{fold}th_fold_dual_outputs_m6_info-no_promoter-False_MOTIF.csv"
    validation_df = pd.read_csv(validation_file)
    plot_correlation(validation_df["true_control"], validation_df["pred_control"], title=f"{fold}-Fold Control Data", interactive=True)
    plot_correlation(validation_df["true_case"], validation_df["pred_case"], title=f"{fold}-Fold Case Data", interactive=True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 6
#       4 validation_df = pd.read_csv(validation_file)
#       5 plot_correlation(validation_df["true_control"], validation_df["pred_control"], title="Control Data", interactive=True)
# ----> 6 plot_correlation(validation_df["true_case"], validation_df["pred_case"], title="Case Data", interactive=True)
#
# File /binf-isilon/renniegrp/vpx267/ucph_thesis/wrapper/utils.py:153, in plot_correlation(y_true, y_pred, output_path, output_name, title, interactive)
#     151 # Calculate the point density
#     152 xy = np.vstack([y_true, y_pred])
# --> 153 z = gaussian_kde(xy)(xy)
#     154 corr_coef = np.corrcoef(y_true, y_pred)[0, 1]
#     155 color_palette = "rocket"
#
# ...
